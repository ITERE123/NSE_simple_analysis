# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# lLOAD DATA
df = pd.read_csv(r"C:\Users\oweni\Downloads\NSE_data_stock_market_sectors_2025.csv")
# display the first few rows of the dataframe
df.head()
# Out:
#          Sector Stock_code               Stock_name
# 0  Agricultural       EGAD              Eaagads Ltd
# 1  Agricultural       KUKZ               Kakuzi Plc
# 2  Agricultural       KAPC  Kapchorua Tea Kenya Plc
# 3  Agricultural       LIMT           Limuru Tea Plc
# 4  Agricultural       SASN               Sasini Plc

# %%
#get summary statistics of the dataframe
df.describe()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sector      75 non-null     str
#  1   Stock_code  75 non-null     str
#  2   Stock_name  75 non-null     str
# dtypes: str(3)
# memory usage: 4.9 KB

# %%
df["Sector"].value_counts()
# Out:
# Sector
# Commercial and Services          13
# Banking                          11
# Manufacturing and Allied          9
# Indices                           8
# Agricultural                      6
# Energy and Petroleum              6
# Insurance                         6
# Construction and Allied           5
# Investment                        5
# Exchange Traded Funds             2
# Automobiles and Accessories       1
# Investment Services               1
# Telecommunication                 1
# Real Estate Investment Trusts     1
# Name: count, dtype: int64

# %%
fig = px.histogram(
    df, 
    x="Sector", 
    title="Distribution of Sectors in the NSE Stock Market"
)

# Use categoryorder to sort by the number of occurrences
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.show()

# %%
# Check the number of unique stock codes in the dataset
df["Stock_code"].nunique()
df["Stock_code"].head()
# Out:
# 0    EGAD
# 1    KUKZ
# 2    KAPC
# 3    LIMT
# 4    SASN
# Name: Stock_code, dtype: str

# %%
# Calculate the percentage of each sector in the dataset
percentages = df["Sector"].value_counts(normalize=True) * 100
print(round(percentages, 2))
# Out:
# Sector
# Commercial and Services          17.33
# Banking                          14.67
# Manufacturing and Allied         12.00
# Indices                          10.67
# Agricultural                      8.00
# Energy and Petroleum              8.00
# Insurance                         8.00
# Construction and Allied           6.67
# Investment                        6.67
# Exchange Traded Funds             2.67
# Automobiles and Accessories       1.33
# Investment Services               1.33
# Telecommunication                 1.33
# Real Estate Investment Trusts     1.33
# Name: proportion, dtype: float64
